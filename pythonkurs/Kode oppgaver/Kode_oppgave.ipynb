# %% [markdown]
# # Python oppgaver

# %% [markdown]
# ## Oppgave 1

# %% [markdown]
# Du er gitt følgende variabler:
# - En liste som du ikke vet innholdet til `mystery_list`.
# - `variable_1`, `variable_2` og  `variable_3`.
#
#
# a) Lag en tuppel som inneholder `variable_1`, `variable_2` og  `variable_3`(i denne rekkefølgen).
#
# b) Finn typen til `variable_3`.
#
# c) Lag en liste som kun inneholder elementer av typen int eller float i `mystery_list`. Rekkefølgen av tallene skal være bevart. Dette vil si at alle elementer som ikke er av typen `float` eller `int` skal fjernes.
#
# For eksempel om `mystery_list = [1, 'hei', 1.5]` hadde svaret blitt `mystery_numbers = [1, 1.5]`

# %%
import pickle
with open('Støttefiler/mystery_list.pkl', 'rb') as f:
   mystery_list = pickle.load(f)


variable_1 = "hei :)"
variable_2 = [1, 2.3]
variable_3 = 1 + True
# ------------- ikke endre noe over denne linjen -------------------------

# a) Lag en tuppel som inneholder variable_1, variable_2 og variable_3.
tuple_of_variables = 

# b) Finn typen til variable_3.
type_variable_3 = 

# c) Lag en liste som kun inneholder tallene i listen mystery_list.
mystery_numbers =

# %% [markdown]
# ## Oppgave 2

# %% [markdown]
# I den oppgaven har vi prøvd å bruke eulers metode på differensialligningen
#
# $$y′(x)=e−x−y(x),\, y(0)=4.$$
# Vi bruker skrittlengde $0.2$ og har prøvd å estimere verdien til $y$ i punktet $x=2$.
#
# Dessverre kjører ikke koden. Finn feilen/ene slik at koden kjører korrekt.
#
# Hint: Oppgaven er lettere å løse på egen datamaskin hvor du kan lese feilmeldingen som blir gitt.

# %%
from math import exp

x_0 = 0
y_0 = 4

step_length = 0.2

for i in range(100):
y_derivative = exp(-x_0 - step_length*i) - y
y = y + step_length * y_derivative

# %% [markdown]
# ## Oppgave 3

# %% [markdown]
# I denne oppgaven skal vi lage vektorer i numpy, også kalt `1darray`, ved å bruke forskjellige metoder. Ingen av deloppgavene skal løses med mer enn en linje med kode.
#
# a) Importe`r num`py pakken med alia`s `np.
#
# b) Gjør om lis`ten list_of_num`bers til en vektor.
#
# c) Lag en vektor med heltall mellom 2 og 132 (med begge endepunktene inkludert).
#
# d) Lag en vektor med 100 punkter med lik avstand mellom 2 og 5. Vektoren skal begynne med punktet 2.00 og ende med punktet 5.00.

# %%
# a) Importer numpy pakken med alias np.


# b) Gjør om listen list_of_numbers til en vektor.

list_of_numbers = [0, 1.2, 3, 2.5]

vector_b = 

# c) Lag en vektor med heltall mellom 2 og 132.

vector_c = 

# d) Lag en vektor med 100 punkter med lik avstand mellom 2 og 5.

vector_d =

# %% [markdown]
# ## Oppgave 4

# %% [markdown]
# Finn funksjonsverdiene til funksjonen.
#
# a) Lag 200 verdier mellom 0 og 5 som vi kommer til å lagre som `x_values`. Første verdi i vektoren skal være 0, og siste verdi skal være 5.
#
# b) La $f(x)=x^5/2−3x+2$. Bruk $f$ på alle verdiene i vektoren `x_values`.
#
# c) La $g(x)=\sin(2\pi x)+\exp(6x)$. Bruk $g$ på alle verdiene i vektoren `x_values`. Husk at $\exp(x)=e^x$.
#
# d) Definer $h(x)=f(x)\cdot g(x)$. Bruk $h$ på alle verdiene i vektoren `x_values`.

# %%
import numpy as np

# a) Lag 200 verdier mellom 0 og 5 som vi kommer til å lagre som x_values.
x_values = 

# b) La f(x)=x^5/2-3x+2. Bruk f på alle verdiene i vektoren x_values.
f = 

# c) La g(x)=sin(2 pi x)+exp(6x). Bruk g på alle verdiene i vektoren x_values.
g = 

# d) Definer h(x)=f(x)g(x). Bruk h på alle verdiene i vektoren x_values.
h =

# %% [markdown]
# ## Oppgave 5

# %% [markdown]
# I denne oppgaven skal vi lage komplekse vektorer.
#
# a) Lag vektoren som består av $$\vec{v}=(1+i, 2+i, i, 8+30i, -2+1.1i, -0.5, 8+3i, 5+12i).$$
#
# Husk at $i$ ingeniørfag har vi at den imaginære enheten $i$ ofte skrives som $j$. Det vil si at vektoren $$\vec{v}=(1+j, 2+j, j, 8+30j, -2+1.1j, -0.5, 8+3j, 5+12j).$$
#
# b) Finn absoluttverdien, realdelen og imaginærdelen av elementene i vektoren $\vec{v}$.

# %%
import numpy as np

# a) Lag vektoren som består av v=(1+i, 2+i, i, 8+30i, -2+1.1i, -0.5, 8+3i, 5+12i). 
complex_vector = 

# b) Finn absoluttverdien, reele delen og imaginære delen av vektoren v.
real_complex_vector = 
imaginary_complex_vector = 

absolute_complex_vector =

# %% [markdown]
# ## Oppgave 6

# %% [markdown]
# I denne oppgaven skal vi lage matriser på ulike metoder. Løsningene på hver deloppgave skal være under en linje.
#
# a) Lag en matrise ved å bruke listen av lister. Listen av lister du skal bruke heter `list_of_lists`.
#
# b) Lag en matrise med tallene 0 til 99 med 10 rader og 10 kolonner.
#
# c) Legg sammen matrisene `matrix_1` og `matrix_2` ved siden av hverandre i rekkefølgen `matrix_1` og `matrix_2`.
#
# d) Legg sammen matrisene `matrix_1` og `matrix_2` under hverandre, med `matrix_1` på topp og `matrix_2` underst.
#
# e) Gjør om matrisen `matrix_1` til en vektor.

# %%
import numpy as np

matrix_1, matrix_2 = np.load("Støttefiler/random_matrix.npy")
# ------------- ikke endre noe over denne linjen -------------------------

# a) Lag en matrise ved å bruke listen av lister.
list_of_lists = [[1, 2, 1, 8, 10], [2, 9, 10, 2, 1], [1, 2, 0, -1, -10]]
matrix_from_lists = 

# b) Lag en matrise med tallene 0 til 99 med 10 rader og 10 kolonner.
matrix_hundred = 

# c) Legg sammen matrisene matrix_1 og matrix_2 ved siden av hverandre
#      i rekkefølgen matrix_1 og matrix_2.
matrix_horizontal_stacked = 

# d) Legg sammen matrisene matrix_1 og matrix_2 under hverandre, med 
#      matrix_1 på topp og matrix_2 underst.
matrix_vertical_stacked = 

# e) Gjør om matrisen matrix_1 til en vektor.
matrix_vector =

# %% [markdown]
# ## Oppgave 7

# %% [markdown]
# I denne oppgaven skal se på matriser. Du blir gitt en ukjent matrise kalt `mystery_matrix`.
#
# a) Hvor mange rader og kolonner har matrisen `mystery_matrix`?
#
# b) Lagre rad 10 i matrisen `mystery_matrix` som variabelen `row_10`. (Merk at python teller fra null, så for eksempel er rad 1 det samme som rad 0 i python.)
#
# c) Lagre den siste kolonnen i matrisen `mystery_matrix` som `last_column`.
#
# d) Lag matrisen som består av de 10 første radene og kolonnene av matrisen `mystery_matrix`. (Radene og kolonnene er telt fra 1, ikke fra 0 som.)

# %%
import numpy as np
mystical_matrix = np.load('Støttefiler/mystical_matrix.npy')
# ------------- ikke endre noe over denne linjen -------------------------

# a) Hvor mange rader og kolonner har matrisen matrise?

number_of_rows_matrix = 
number_of_columns_matrix =

# b) Lagre rad 10 i matrisen mystery_matrix som variabelen row_10.

row_10 = 

# c) Lagre den siste kolonnen i matrisen mystery_matrix som last_column.

last_column = 

# d) Lag matrisen som består av de 10 første radene og kolonnene av 
#       matrisen mystery_matrix.

upper_right_matrix =

# %% [markdown]
# ## Oppgave 8

# %% [markdown]
# Et busselskap får hver dag inn data fra en bussrute som forteller når bussen stopper på hvert stopp. Denne dataen blir lagret i en vektor. De ønsker å få en daglig oppsummering på hvor mye bussen er forsinket. For å ikke repetere kode skal du lage en funksjon med navn `daily_summary`.
#
# Denne funksjonen skal ta inn følgende:
#
# - En vektor kallt todays_bus_times som inneholder når bussene gikk fra busstoppet.
# - En vektor kallt timetable_bus_times som inneholder rutetabellen.
#
# Den skal returnere en tuppel med følgende:
#
# - Gjennomsnittelig avvik fra timetabellen, gitt via formelen $$\frac{1}{n}\sum_{i=1}^n |\mathrm{todays\_bus\_times[i]}-\mathrm{timetable\_bus\_times[i]}|.$$
# - Variansen fra timetabellen, gitt via formelen $$\frac{1}{n-1}\sum_{i=1}^n (\mathrm{todays\_bus\_times[i]}-\mathrm{timetable\_bus\_times[i]})^2.$$

# %%
import numpy as np

# %% [markdown]
# ## Oppgave 9

# %% [markdown]
# La $f(x,y)$ være høyden på et havbunnen på  målt over kvadrat med lengde på 10 meter. Siden vi ikke kan måle i hvert eneste punkt, har vi målt høyden hver halvmeter ($\Delta h = 0.5$), hvor vi har begynt i et hjørne. Det vil si at vi har gjort $21\times21=441$ målinger som vi har lagret i matrisen `seafloor_height`. I dette tilfelle er `seafloor_height[i, j]` målingen i punktet $(i\Delta h,j\Delta h)$ hvor $i,j = 0,1,2,\dots ,20$.
#
# Vi ønsker å finne en tilnærming til de partiellderiverte ved å bruke formelene
#
# $$\frac{\partial f (i\Delta h, j\Delta h)}{\partial x}=\frac{ f ((i+1)\Delta h, j\Delta h)-f (i\Delta h, j\Delta h)}{\Delta h }$$
#
# og
#
# $$\frac{\partial f (i\Delta h, j\Delta h)}{\partial y}=\frac{ f (i\Delta h, (j+1)\Delta h)-f (i\Delta h, j\Delta h)}{\Delta h }.$$
#
# a) Lag matrisene med alle radene utenom
#   - den første kolonnen og kall den `f_ipluss1_j`.
#   - siste kolonnen `f_without_last_column`.
#
# b) Bruk matrisene i oppgave a) for å lage $f_x$ som består av de partiellderiverte i $x$-retningen.
#
# c) Bruk en lignende metode for å lage matrisen $f_y$ som består av de partiellderiverte $y$-retningen.

# %%
import numpy as np

step_length = 0.5
seafloor_height = np.load("Støttefiler/seafloor.npy")
# ------------- ikke endre noe over denne linjen -------------------------



# a) Lag matrisene med alle radene utenom den 
#        første kollonen og kall den f_ipluss1_j.
#        siste kollonen f_i_j.
f_ipluss1_j = 
f_without_last_column = 

# b) Lag matrisen f_x som består av de partiellderiverte i x-retningen.
f_x = 

# c) Lag matrisen f_y som består av de partiellderiverte y-retningen.
f_y =

# %% [markdown]
# ## Oppgave 10

# %% [markdown]
# I denne oppgaven skal vi finne taylorpolynomet av tredje orden til funksjonen $f(x)=e^{2x}−2$ sentrert i punktet $x=0$.
#
# a) Lag en vektor som består av 200 punkter som starter i -1 og slutter i 1. Vektoren skal hete `x_values`. Evaluer funksjonen $f$ i verdiene i vektoreren.
#
# b) Finn taylorpolynomet av tredje orden $a+bx+cx^2+dx^3$ for funksjonen $f$ og evaluer `x_values` i taylorpolynomet.
#
# c) Finn den største avstanden mellom taylorpolynomet og funksjonsverdiene.

# %%
import numpy as np

# a) Lag en vektor som består av 200 punkter som starter i -1 og slutter i 1.
#      Evaluer funksjonen f i verdiene i vektoreren.
x_values = 
function_values = 


# b) Finn taylorpolynomet av tredje orden for funksjonen f og evaluer x_values 
#      i taylorpolynomet.
taylor_polynomial = 

# c) Finn den største feilen mellom taylorpolynomet og funksjonsverdiene.
maximum_error =

# %% [markdown]
# ## Oppgave 11

# %% [markdown]
# I denne oppgaven skal vi plotte kurven $\gamma(t)=(e^t,\cos(2t))$ på intervallet $t\in[0,2\pi]$.
#
# a) Lag 102 punkter i intervallet som starter i $0$ og slutter i $2\pi$.
#
# b) Lag $x$- og $y$-koordinaten til kurven $\gamma$, som vi kommer til å kalle `gamma_1` og `gamma_2`.

# %%
import matplotlib.pyplot as plt # Pakke brukt til plotting
import numpy as np # Pakke brukt til numeriske beregninger

# a) Lag 102 punkter i intervallet som starter 0 og 2pi.
t = 

# b) Lag x- og y-koordinaten til kurven gamma.
gamma_1 = 
gamma_2 = 

plt.plot(gamma_1, gamma_2)
plt.show()

# %% [markdown]
# ## Oppgave 12

# %% [markdown]
# I denne oppgaven skal vi plotte funksjonen $f(x,y)=e^{−x}\sin(y)$ definert på rektangelet $[0,2]\times[0,4]$.
#
# a) Lag $x$ verdiene som starter i 0 og slutter i 2, med 100 punkter.
#
# b) Lag $y$ verdiene som starter i 0 og slutter i 4, med 200 punkter.
#
# c) Sett inn $x$ og $y$ verdiene for å få et rutenett. Her kan funksjonen `np.meshgrid` være til hjelp.
#
# d) Sett in $x$ og $y$ verdiene i funksjonen $f$.

# %%
import matplotlib.pyplot as plt # Pakke brukt til plotting
import numpy as np
# ------------- ikke endre noe over denne linjen -------------------------

# a) Lag \(x\) verdiene som starter i \(0\) og slutter i \(2\), med \(100\) punkter.
x_values = 

# b) Lag \(y\) verdiene som starter i \(0\) og slutter i \(4\), med \(200\) punkter.
y_values = 

# c) Sett inn x og y verdiene for å få et rutenett.
x, y = 

# d) Sett in x og y verdiene i funksjonen f.
f = 

fig = plt.figure(figsize=(15, 15))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x,y,f)
plt.show()

# %% [markdown]
# ## Oppgave 13

# %% [markdown]
# I denne oppgaven skal vi gjøre noen vanlige linær algebra oprerasjoner i python. Som vi har lært kan vi definere en funksjon ved å matrisemultiplikasjon. La $A$ være en matrise.
#
# a) Lag funksjonsverdiene til funksjonen $f(x,y)= A \begin{bmatrix}x\_vec[i]\\ y\_vec[i]\end{bmatrix}$ for alle verdier av i. Hvor hva `x_vec` og `y_vec` er gitt i opppgaven.
#
# b) Finn inversmatrisen til $A$.
#
# c) Finn vektoren $(x,y)$ slik at $A\begin{bmatrix}x\\ y\end{bmatrix}=\begin{bmatrix}1\\2\end{bmatrix}$.
#
# d) Finn determinanten og den transponerte av $A$.

# %%
import numpy as np
import numpy.linalg as linalg

# x og y verdier
x_vec = np.linspace(0, 1, 100)
y_vec = np.linspace(0, 1, 100)

# Matrix A
A = np.array([[1, 2], [-4, 10]])
# ------------- ikke endre noe over denne linjen -------------------------


# a) Lag funksjonsverdiene til funksjonen 
f = 

# b) Finn inversmatrisen til A.
A_inverse = 

# c) Finn vektoren (x,y) slik at (1,2).
vector = np.array([1, 2])
solution = 

# d) Finn determinanten og den transponerte av A.
determinant_A = 
transpose_A =

# %% [markdown]
# ## Oppgave 14

# %% [markdown]
# Du har samlet inn data om alderen til studenter i klassen for å analysere videre. Dessverre når du ser på alderen til studentene har noen av studentene skrevet inn åpenbar feil informasjon. For eksempel har noen skrevet inn at de er 229 år og en annen student har skrevet at alderen er 2 år.  Noen av studentene har også ikke skrevet inn alderen sin.
#
# Du tenker at du skal fjerne aldere som ikke gir mening før du analyserer dataen videre.
#
# a) De studentene som ikke har skrevet inn alderen sin blir lagret som `NaN`. Verdien `NaN` står for "Not a Number". Finn ut hva funksjonen `np.isnan` gjør, og bruk den til å fjerne `NaN` verdiene i vektoren.
#
# b) Fjern aldere under 15 år og over 80 år. Det vil si at alderen 15 og 80 skal være inkludert, men under og over skal bli fjernet.

# %%
import numpy as np

age_students = np.load("Støttefiler/age_students.npy")
# ------------- ikke endre noe over denne linjen -------------------------

# a) Finn ut hva funksjonen np.isnan gjør, og bruk den til å fjerne NaN 
#     verdiene i vektoren.

age_students_without_nan = 

# b) Fjern aldere under 15 år og over 80 år.

valid_age_students =

# %% [markdown]
# ## Oppgave 15

# %% [markdown]
# Oppgaven er å finne feilen i følgende kode.
#
# Koden skal egentlig gjøre følgende:
#
# Vi har samlet inn informasjon om styrken på stål i en matrise. Vi har delt inn styrkeprøvene i to grupper:
#
# - Rad null består av 20 prøver av helt nytt stål.
# - Rad en består av 20 prøver av stål som har vært ute i et år.
# Vi ønsker å konvertere radene fra enheten pascal til enheten bar. Deretter vil vi finne gjennomsnittelig styrke i både pascal og bar.
#
# Hint: Koden git ikke ut rett svar, og gjennomsnittet i pascal og bar blir beregnet til å være like.

# %%
import numpy as np

steel_strength_Pa = np.load("Støttefiler/steel_strength.npy")

# Gjør hver av radene til bar
steel_strength_bar = steel_strength_Pa
steel_strength_bar[0] = 0.00001 * steel_strength_bar[0]
steel_strength_bar[1] = 0.00001 * steel_strength_bar[1]

# Gjenomsnitt av rader for pascal
mean_strength_Pa = steel_strength_Pa.mean(axis=1) 

# Gjenomsnitt av rader for bar
mean_strength_bar = steel_strength_bar.mean(axis=1)

# %% [markdown]
# ## Oppgave 16

# %% [markdown]
# I denne oppgaven skal vi summere to heltallsvektorer på hverandre, men noe er galt. Fiks koden slik at vektorene blir summert med hverandre.
#
# Hint: Oppgaven er lettere å løse på egen datamaskin hvor man kan lese feilmeldingen som blir gitt.

# %%
import numpy as np

random_vector_1, random_vector_2 = np.load("Støttefiler/random_int_vectors.npy")

addition_of_vector =  random_vector_1 + random_vector_2

# %% [markdown]
# ## Oppgave 17

# %% [markdown]
# I denne oppgaven skal du lage en funksjon som printer ut trær som skal hete `print_tree`. Funksjonen skal ta inn et tall som forteller hvor mange nivåer treet skal ha.
#
# Eksempler på bruk:
#
# - `print_tree(1)` skal utføre handlingen `print("/\\\n||")`.
# - `print_tree(2)` skal utføre handlingen `print(" /\\\n/||\\\n ||")`.
# - `print_tree(3)` skal utføre handlingen `print("  /\\\n /||\\\n/||||\\\n  ||")`.

# %% [markdown]
# ## Oppgave 18

# %% [markdown]
# Hver eneste dag loggfører du hvor mye vekt du løfter i en numpy array. Du ønsker å lage en funsjon som finner en topp n liste over vektløft og returnerer denne vektoren. Funksjonen `top_n` skal ta inn en numpy array og et tall n som forteller hvor mange topprekorder du skal returnere. Du skal kunne velge om vektoren skal være sortert fra størst til minst, eller fra minst til størst.
#
# Eksempler på bruk:
#
# `weight_lift = np.array([20, 15, 13, 18, 25.5, 30, 14])`
#
# - `top_n(1, weight_lift, max_to_min=False)` skal returnere `np.array([30])`.
# - `top_n(2, weight_lift, max_to_min=False)` skal returnere `np.array([25.5, 30])`.
# - `top_n(3, weight_lift, max_to_min=True)` skal returnere `np.array([30, 25.5, 20])`.

# %%
import numpy as np

def top_n(n, weight, max_to_min):

# %% [markdown]
# ## Oppgave 19

# %% [markdown]
# I denne oppgaven er du gitt et gråskala bilde som er representert med en matrise. Fargen på pikslene er en verdi mellom 0 og 1, hvor 0 er svart og 1 er hvit. For eksempel, representerer `np.array([[0, 0.6], [0.2, 1]])` bildet
#
# ![svart_hvit_bilde.PNG](attachment:e7778c8f-b569-4fd8-be89-45dedb880984.PNG)
#
# Lag en hvit ramme rundt bildet astronaut på 20 piksler i hver retning. Det endelige bildet skal se slik ut:
#
# ![final.PNG](attachment:5da91297-f9ab-4b78-8cf6-3a4480731a65.PNG)

# %%
import numpy as np

astronaut = np.load("Støttefiler/astronaut.npy")
# ------------- ikke endre noe over denne linjen -------------------------

astronaut_with_boundary =

# %% [markdown]
# ## Oppgave 20

# %% [markdown]
# La $a_0=0$, og $a_1=2$ og definer $$a_n=3a_{n−1}−a_{n−2}.$$
# Det vil for eksempel si at $a_2=3\cdot 2−0=6$.
#
# Hva er $n$ og $a_n$ første gang $a_n>10^6$?
#
#
#
# Hint: Du kan løse oppgaven med en while-løkke.

# %%
n =

a_n =
